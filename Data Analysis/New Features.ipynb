# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
# Define the seasons and their date ranges
seasons = {
    'S2024/2025': ('2024-07-20', '2025-06-15'),
    'S2023/2024': ('2023-07-20', '2024-06-15'),
    'S2022/2023': ('2022-07-20', '2023-06-15'),
    'S2021/2022': ('2021-07-20', '2022-06-15'),
    'S2020/2021': ('2020-07-20', '2021-06-15'),
    'S2019/2020': ('2019-07-20', '2020-06-15'),
}

# Convert date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Function to determine season based on date
def determine_season(date, season_dict):
    for season, (start_date, end_date) in season_dict.items():
        if start_date <= date.strftime('%Y-%m-%d') <= end_date:
            return season
    return 'Unknown Season'  # Return if date doesn't fit any range

# Apply the function to create a season column
df['season'] = df['Date'].apply(lambda x: determine_season(x, seasons))

# %%
# Define a function to calculate points
def calculate_points(ftr):
    if ftr == 'H':
        return (3, 0)  # Home wins
    elif ftr == 'D':
        return (1, 1)  # Draw
    elif ftr == 'A':
        return (0, 3)  # Away wins

# Apply the function to the DataFrame
df[['HomeTeamPoints', 'AwayTeamPoints']] = df['FTR'].apply(lambda x: pd.Series(calculate_points(x)))

# %%
import pandas as pd

#Sum the HomeTeamPoints for each team per season
home_team_points = df.groupby(['season', 'HomeTeam'])['HomeTeamPoints'].sum().reset_index()
home_team_points = home_team_points.rename(columns={'HomeTeamPoints': 'TotalHomePoints'})

#Sum the AwayTeamPoints for each team per season
away_team_points = df.groupby(['season', 'AwayTeam'])['AwayTeamPoints'].sum().reset_index()
away_team_points = away_team_points.rename(columns={'AwayTeamPoints': 'TotalAwayPoints'})

#Rank teams based on TotalHomePoints for each season
home_team_points['HomeTeamStrength'] = home_team_points.groupby('season')['TotalHomePoints'].rank(ascending=False, method='min')

#Rank teams based on TotalAwayPoints for each season
away_team_points['AwayTeamStrength'] = away_team_points.groupby('season')['TotalAwayPoints'].rank(ascending=False, method='min')

#Merge the rankings back into the original DataFrame for HomeTeam and AwayTeam separately
df = df.merge(home_team_points[['season', 'HomeTeam', 'HomeTeamStrength']], on=['season', 'HomeTeam'], how='left')
df = df.merge(away_team_points[['season', 'AwayTeam', 'AwayTeamStrength']], on=['season', 'AwayTeam'], how='left')

# %%
import pandas as pd

# Assuming you have a DataFrame 'df' with these columns:
# 'HomeTeam', 'AwayTeam', 'season', 'FTHG', 'FTAG', 'HTHG', 'HTAG', 'HST', 'AST', 'HR', 'AR'

# Step 1: Calculate averages for HomeTeam statistics per season
home_team_avg = df.groupby(['season', 'HomeTeam']).agg({
    'FTHG': 'mean',
    'HTHG': 'mean',
    'HST': 'mean',
    'HR': 'mean'
}).reset_index()

# Rename columns to represent HomeTeam stats
home_team_avg = home_team_avg.rename(columns={
    'FTHG': 'avgHG',   # Average Full Time Home Goals
    'HTHG': 'avgHHG',  # Average Half Time Home Goals
    'HST': 'avgHST',   # Average Home Shots on Target
    'HR': 'avgHR'      # Average Home Red Cards
})

# Step 2: Calculate averages for AwayTeam statistics per season
away_team_avg = df.groupby(['season', 'AwayTeam']).agg({
    'FTAG': 'mean',
    'HTAG': 'mean',
    'AST': 'mean',
    'AR': 'mean'
}).reset_index()

# Rename columns to represent AwayTeam stats
away_team_avg = away_team_avg.rename(columns={
    'FTAG': 'avgAG',   # Average Full Time Away Goals
    'HTAG': 'avgHAG',  # Average Half Time Away Goals
    'AST': 'avgAST',   # Average Away Shots on Target
    'AR': 'avgAR'      # Average Away Red Cards
})

# Step 3: Merge these averages back into the original DataFrame
# Merge home team averages
df = df.merge(home_team_avg, on=['season', 'HomeTeam'], how='left')

# Merge away team averages
df = df.merge(away_team_avg, on=['season', 'AwayTeam'], how='left')

# %%
df.to_csv('ML_data.csv', index=False)

# %%
df.head(50)
# Out:
#    Div       Date      Time             HomeTeam             AwayTeam  FTHG  \
# 0   B1 2024-09-01  18:15:00             Kortrijk           St Truiden   1.0
# 1   B1 2024-09-01  17:30:00         St. Gilloise           Anderlecht   0.0
# 2   B1 2024-09-01  15:00:00                 Gent              Antwerp   1.0
# 3   B1 2024-09-01  12:30:00          Club Brugge        Cercle Brugge   3.0
# 4   B1 2024-08-31  19:45:00  Oud-Heverlee Leuven             Standard   2.0
# 5   B1 2024-08-31  17:15:00         Beerschot VA               Dender   1.0
# 6   B1 2024-08-31  15:00:00             Mechelen            Charleroi   5.0
# 7   B1 2024-08-30  19:45:00                 Genk             Westerlo   1.0
# 8   B1 2024-08-25  18:15:00            Charleroi             Kortrijk   1.0
# 9   B1 2024-08-25  17:30:00             Standard         Beerschot VA   1.0
# 10  B1 2024-08-25  15:00:00           St Truiden         St. Gilloise   0.0
# 11  B1 2024-08-25  12:30:00               Dender          Club Brugge   1.0
# 12  B1 2024-08-24  19:45:00              Antwerp             Mechelen   0.0
# 13  B1 2024-08-24  17:15:00             Westerlo  Oud-Heverlee Leuven   1.0
# 14  B1 2024-08-18  18:15:00                 Gent             Westerlo   4.0
# 15  B1 2024-08-18  17:30:00             Kortrijk             Standard   1.0
# 16  B1 2024-08-18  15:00:00  Oud-Heverlee Leuven        Cercle Brugge   1.0
# 17  B1 2024-08-18  12:30:00          Club Brugge              Antwerp   1.0
# 18  B1 2024-08-17  19:45:00             Mechelen           Anderlecht   1.0
# 19  B1 2024-08-17  17:15:00           St Truiden               Dender   3.0
# 20  B1 2024-08-17  15:00:00         Beerschot VA                 Genk   3.0
# 21  B1 2024-08-16  19:45:00         St. Gilloise            Charleroi   1.0
# 22  B1 2024-08-11  18:15:00        Cercle Brugge         Beerschot VA   4.0
# 23  B1 2024-08-11  17:30:00            Charleroi                 Gent   1.0
# 24  B1 2024-08-11  15:00:00              Antwerp           St Truiden   6.0
# 25  B1 2024-08-11  12:30:00                 Genk          Club Brugge   3.0
# 26  B1 2024-08-10  19:45:00           Anderlecht  Oud-Heverlee Leuven   1.0
# 27  B1 2024-08-10  17:15:00             Westerlo         St. Gilloise   4.0
# 28  B1 2024-08-10  15:00:00               Dender             Kortrijk   4.0
# 29  B1 2024-08-09  19:45:00             Standard             Mechelen   0.0
# 30  B1 2024-08-04  18:15:00                 Gent               Dender   1.0
# 31  B1 2024-08-04  17:30:00             Standard          Club Brugge   1.0
# 32  B1 2024-08-04  15:00:00        Cercle Brugge             Kortrijk   1.0
# 33  B1 2024-08-04  12:30:00              Antwerp           Anderlecht   1.0
# 34  B1 2024-08-03  19:45:00           St Truiden            Charleroi   1.0
# 35  B1 2024-08-03  17:15:00  Oud-Heverlee Leuven                 Genk   3.0
# 36  B1 2024-08-03  15:00:00             Mechelen             Westerlo   2.0
# 37  B1 2024-08-02  19:45:00         St. Gilloise         Beerschot VA   3.0
# 38  B1 2024-07-28  18:15:00             Westerlo        Cercle Brugge   3.0
# 39  B1 2024-07-28  17:30:00            Charleroi              Antwerp   0.0
# 40  B1 2024-07-28  15:00:00             Kortrijk                 Gent   0.0
# 41  B1 2024-07-28  12:30:00                 Genk             Standard   0.0
# 42  B1 2024-07-27  19:45:00           Anderlecht           St Truiden   1.0
# 43  B1 2024-07-27  17:15:00         Beerschot VA  Oud-Heverlee Leuven   0.0
# 44  B1 2024-07-27  15:00:00               Dender         St. Gilloise   0.0
# 45  B1 2024-07-26  19:45:00          Club Brugge             Mechelen   1.0
# 46  B1 2024-06-02  12:30:00                 Genk                 Gent   0.0
# 47  B1 2024-05-26  17:30:00              Antwerp           Anderlecht   3.0
# 48  B1 2024-05-26  17:30:00          Club Brugge        Cercle Brugge   0.0
# 49  B1 2024-05-26  17:30:00         St. Gilloise                 Genk   2.0
#
#     FTAG FTR  HTHG  HTAG  ... HomeTeamStrength  AwayTeamStrength     avgHG  \
# 0    1.0   D   0.0   1.0  ...              8.0              13.0  0.666667
# 1    0.0   D   0.0   0.0  ...              1.0               1.0  1.333333
# 2    1.0   D   1.0   1.0  ...              8.0               4.0  2.000000
# 3    0.0   H   2.0   0.0  ...              1.0              13.0  1.666667
# 4    0.0   H   1.0   0.0  ...              1.0              13.0  2.000000
# 5    2.0   A   0.0   2.0  ...             16.0               1.0  1.333333
# 6    2.0   H   3.0   2.0  ...             12.0               5.0  2.666667
# 7    0.0   H   0.0   0.0  ...              1.0               5.0  1.333333
# 8    0.0   H   1.0   0.0  ...              7.0               5.0  0.666667
# 9    0.0   H   0.0   0.0  ...              1.0              16.0  0.666667
# 10   0.0   D   0.0   0.0  ...             15.0              12.0  1.333333
# 11   2.0   A   1.0   2.0  ...              8.0               5.0  1.666667
# 12   1.0   A   0.0   1.0  ...             12.0               3.0  2.333333
# 13   1.0   D   1.0   1.0  ...              1.0               5.0  2.666667
# 14   1.0   H   3.0   1.0  ...              8.0               5.0  2.000000
# 15   0.0   H   0.0   0.0  ...              8.0              13.0  0.666667
# 16   1.0   D   1.0   1.0  ...              1.0              13.0  2.000000
# 17   0.0   H   0.0   0.0  ...              1.0               4.0  1.666667
# 18   3.0   A   1.0   2.0  ...             12.0               1.0  2.666667
# 19   3.0   D   2.0   1.0  ...             15.0               1.0  1.333333
# 20   4.0   A   1.0   3.0  ...             16.0               5.0  1.333333
# 21   0.0   H   0.0   0.0  ...              1.0               5.0  1.333333
# 22   1.0   H   3.0   1.0  ...             12.0              16.0  2.500000
# 23   0.0   H   0.0   0.0  ...              7.0               5.0  0.666667
# 24   1.0   H   2.0   0.0  ...             12.0              13.0  2.333333
# 25   2.0   H   0.0   1.0  ...              1.0               5.0  1.333333
# 26   1.0   D   1.0   1.0  ...              8.0               5.0  1.000000
# 27   3.0   H   3.0   1.0  ...              1.0              12.0  2.666667
# 28   1.0   H   2.0   1.0  ...              8.0               5.0  1.666667
# 29   0.0   D   0.0   0.0  ...              1.0               3.0  0.666667
# 30   2.0   A   0.0   1.0  ...              8.0               1.0  2.000000
# 31   0.0   H   0.0   0.0  ...              1.0               5.0  0.666667
# 32   2.0   A   1.0   1.0  ...             12.0               5.0  2.500000
# 33   2.0   A   1.0   1.0  ...             12.0               1.0  2.333333
# 34   4.0   A   0.0   4.0  ...             15.0               5.0  1.333333
# 35   1.0   H   2.0   0.0  ...              1.0               5.0  2.000000
# 36   4.0   A   0.0   2.0  ...             12.0               5.0  2.666667
# 37   1.0   H   2.0   0.0  ...              1.0              16.0  1.333333
# 38   0.0   H   1.0   0.0  ...              1.0              13.0  2.666667
# 39   1.0   A   0.0   1.0  ...              7.0               4.0  0.666667
# 40   1.0   A   0.0   0.0  ...              8.0               5.0  0.666667
# 41   0.0   D   0.0   0.0  ...              1.0              13.0  1.333333
# 42   0.0   H   0.0   0.0  ...              8.0              13.0  1.000000
# 43   0.0   D   0.0   0.0  ...             16.0               5.0  1.333333
# 44   0.0   D   0.0   0.0  ...              8.0              12.0  1.666667
# 45   1.0   D   0.0   0.0  ...              1.0               3.0  1.666667
# 46   1.0   A   0.0   0.0  ...              7.0               2.0  1.571429
# 47   1.0   H   0.0   1.0  ...              6.0               4.0  1.950000
# 48   0.0   D   0.0   0.0  ...              3.0               4.0  2.350000
# 49   0.0   H   1.0   0.0  ...              2.0               7.0  2.150000
#
#       avgHHG    avgHST     avgHR     avgAG    avgHAG    avgAST     avgAR
# 0   0.000000  5.666667  0.000000  0.666667  0.333333  3.333333  0.000000
# 1   0.666667  4.666667  0.000000  1.666667  1.000000  5.666667  0.000000
# 2   1.333333  6.333333  0.000000  0.666667  0.666667  5.666667  0.333333
# 3   0.666667  7.333333  0.000000  0.333333  0.333333  4.000000  0.000000
# 4   1.333333  5.000000  0.333333  0.000000  0.000000  0.333333  0.333333
# 5   0.333333  3.666667  0.000000  2.333333  1.333333  5.333333  0.000000
# 6   1.333333  6.666667  0.000000  2.000000  2.000000  4.666667  0.000000
# 7   0.000000  5.000000  0.000000  1.666667  1.000000  5.666667  0.000000
# 8   0.333333  4.333333  0.000000  1.000000  0.666667  3.000000  0.333333
# 9   0.000000  3.000000  0.000000  0.666667  0.333333  2.333333  0.333333
# 10  0.666667  2.000000  0.333333  1.000000  0.333333  4.000000  0.000000
# 11  1.000000  3.666667  0.000000  1.333333  1.000000  5.666667  0.000000
# 12  1.000000  6.333333  0.000000  0.666667  0.333333  2.666667  0.000000
# 13  1.666667  6.000000  0.000000  0.666667  0.666667  4.000000  0.000000
# 14  1.333333  6.333333  0.000000  1.666667  1.000000  5.666667  0.000000
# 15  0.000000  5.666667  0.000000  0.000000  0.000000  0.333333  0.333333
# 16  1.333333  5.000000  0.333333  0.333333  0.333333  4.000000  0.000000
# 17  0.666667  7.333333  0.000000  0.666667  0.666667  5.666667  0.333333
# 18  1.333333  6.666667  0.000000  1.666667  1.000000  5.666667  0.000000
# 19  0.666667  2.000000  0.333333  2.333333  1.333333  5.333333  0.000000
# 20  0.333333  3.666667  0.000000  2.500000  1.500000  6.500000  0.500000
# 21  0.666667  4.666667  0.000000  2.000000  2.000000  4.666667  0.000000
# 22  2.000000  7.000000  0.000000  0.666667  0.333333  2.333333  0.333333
# 23  0.333333  4.333333  0.000000  0.500000  0.000000  1.000000  0.000000
# 24  1.000000  6.333333  0.000000  0.666667  0.333333  3.333333  0.000000
# 25  0.000000  5.000000  0.000000  1.333333  1.000000  5.666667  0.000000
# 26  0.500000  2.500000  0.000000  0.666667  0.666667  4.000000  0.000000
# 27  1.666667  6.000000  0.000000  1.000000  0.333333  4.000000  0.000000
# 28  1.000000  3.666667  0.000000  1.000000  0.666667  3.000000  0.333333
# 29  0.000000  3.000000  0.000000  0.666667  0.333333  2.666667  0.000000
# 30  1.333333  6.333333  0.000000  2.333333  1.333333  5.333333  0.000000
# 31  0.000000  3.000000  0.000000  1.333333  1.000000  5.666667  0.000000
# 32  2.000000  7.000000  0.000000  1.000000  0.666667  3.000000  0.333333
# 33  1.000000  6.333333  0.000000  1.666667  1.000000  5.666667  0.000000
# 34  0.666667  2.000000  0.333333  2.000000  2.000000  4.666667  0.000000
# 35  1.333333  5.000000  0.333333  2.500000  1.500000  6.500000  0.500000
# 36  1.333333  6.666667  0.000000  1.666667  1.000000  5.666667  0.000000
# 37  0.666667  4.666667  0.000000  0.666667  0.333333  2.333333  0.333333
# 38  1.666667  6.000000  0.000000  0.333333  0.333333  4.000000  0.000000
# 39  0.333333  4.333333  0.000000  0.666667  0.666667  5.666667  0.333333
# 40  0.000000  5.666667  0.000000  0.500000  0.000000  1.000000  0.000000
# 41  0.000000  5.000000  0.000000  0.000000  0.000000  0.333333  0.333333
# 42  0.500000  2.500000  0.000000  0.666667  0.333333  3.333333  0.000000
# 43  0.333333  3.666667  0.000000  0.666667  0.666667  4.000000  0.000000
# 44  1.000000  3.666667  0.000000  1.000000  0.333333  4.000000  0.000000
# 45  0.666667  7.333333  0.000000  0.666667  0.333333  2.666667  0.000000
# 46  0.666667  5.619048  0.095238  1.619048  0.809524  5.380952  0.190476
# 47  0.900000  5.350000  0.000000  1.600000  0.850000  5.000000  0.100000
# 48  0.850000  6.200000  0.050000  1.150000  0.450000  4.050000  0.150000
# 49  1.200000  6.750000  0.000000  1.300000  0.550000  4.900000  0.200000
#
# [50 rows x 106 columns]
