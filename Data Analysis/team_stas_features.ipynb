# %%
import pandas as pd

# %%
df = pd.read_csv('final_data.csv')

# %%
# Define the seasons and their date ranges
seasons = {
    'S2024/2025': ('2024-07-20', '2025-06-15'),
    'S2023/2024': ('2023-07-20', '2024-06-15'),
    'S2022/2023': ('2022-07-20', '2023-06-15'),
    'S2021/2022': ('2021-07-20', '2022-06-15'),
    'S2020/2021': ('2020-07-20', '2021-06-15'),
    'S2019/2020': ('2019-07-20', '2020-06-15'),
}

# Convert date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Function to determine season based on date
def determine_season(date, season_dict):
    for season, (start_date, end_date) in season_dict.items():
        if start_date <= date.strftime('%Y-%m-%d') <= end_date:
            return season
    return 'Unknown Season'  # Return if date doesn't fit any range

# Apply the function to create a season column
df['season'] = df['Date'].apply(lambda x: determine_season(x, seasons))

# %%
# Define a function to calculate points
def calculate_points(ftr):
    if ftr == 'H':
        return (3, 0)  # Home wins
    elif ftr == 'D':
        return (1, 1)  # Draw
    elif ftr == 'A':
        return (0, 3)  # Away wins

# Apply the function to the DataFrame
df[['HomeTeamPoints', 'AwayTeamPoints']] = df['FTR'].apply(lambda x: pd.Series(calculate_points(x)))

# %%
import pandas as pd

#Sum the HomeTeamPoints for each team per season
home_team_points = df.groupby(['season', 'HomeTeam'])['HomeTeamPoints'].sum().reset_index()
home_team_points = home_team_points.rename(columns={'HomeTeamPoints': 'TotalHomePoints'})

#Sum the AwayTeamPoints for each team per season
away_team_points = df.groupby(['season', 'AwayTeam'])['AwayTeamPoints'].sum().reset_index()
away_team_points = away_team_points.rename(columns={'AwayTeamPoints': 'TotalAwayPoints'})

#Rank teams based on TotalHomePoints for each season
home_team_points['HomeTeamStrength'] = home_team_points.groupby('season')['TotalHomePoints'].rank(ascending=False, method='min')

#Rank teams based on TotalAwayPoints for each season
away_team_points['AwayTeamStrength'] = away_team_points.groupby('season')['TotalAwayPoints'].rank(ascending=False, method='min')

#Merge the rankings back into the original DataFrame for HomeTeam and AwayTeam separately
df = df.merge(home_team_points[['season', 'HomeTeam', 'HomeTeamStrength']], on=['season', 'HomeTeam'], how='left')
df = df.merge(away_team_points[['season', 'AwayTeam', 'AwayTeamStrength']], on=['season', 'AwayTeam'], how='left')

# %%
import pandas as pd
# 'HomeTeam', 'AwayTeam', 'season', 'FTHG', 'FTAG', 'HTHG', 'HTAG', 'HST', 'AST', 'HR', 'AR', 'B365H', 'B365D', 'B365A'

#Calculate averages for HomeTeam statistics per season
home_team_avg = df.groupby(['season', 'HomeTeam']).agg({
    'FTHG': 'mean',
    'HTHG': 'mean',
    'HST': 'mean',
    'HR': 'mean',
    'AvgH': 'mean',
    'AvgD': 'mean'
}).reset_index()

# Rename columns to represent HomeTeam stats
home_team_avg = home_team_avg.rename(columns={
    'FTHG': 'avgHG',   # Average Full Time Home Goals
    'HTHG': 'avgHHG',  # Average Half Time Home Goals
    'HST': 'avgHST',   # Average Home Shots on Target
    'HR': 'avgHR',      # Average Home Red Cards
    'AvgH': 'avgHomeWinOdds',
    'AvgD': 'avgHomeDrawOdds'
})

# Calculate averages for AwayTeam statistics per season
away_team_avg = df.groupby(['season', 'AwayTeam']).agg({
    'FTAG': 'mean',
    'HTAG': 'mean',
    'AST': 'mean',
    'AR': 'mean',
    'AvgA': 'mean',   
    'AvgD': 'mean'
}).reset_index()

# Rename columns to represent AwayTeam stats
away_team_avg = away_team_avg.rename(columns={
    'FTAG': 'avgAG',   # Average Full Time Away Goals
    'HTAG': 'avgHAG',  # Average Half Time Away Goals
    'AST': 'avgAST',   # Average Away Shots on Target
    'AR': 'avgAR',      # Average Away Red Cards
    'AvgA': 'avgAwayWinOdds',
    'AvgD': 'avgAwayDrawOdds'
})

# Merge these averages back into the original DataFrame
# Merge home team averages
df = df.merge(home_team_avg, on=['season', 'HomeTeam'], how='left')

# Merge away team averages
df = df.merge(away_team_avg, on=['season', 'AwayTeam'], how='left')

# %%
df.to_csv('ML_data_final.csv', index=False)

# %%
df.head(50)
# Out:
#    Div       Date   Time             HomeTeam             AwayTeam  FTHG  \
# 0   B1 2024-09-01  18:15             Kortrijk           St Truiden   1.0
# 1   B1 2024-09-01  17:30         St. Gilloise           Anderlecht   0.0
# 2   B1 2024-09-01  15:00                 Gent              Antwerp   1.0
# 3   B1 2024-09-01  12:30          Club Brugge        Cercle Brugge   3.0
# 4   B1 2024-08-31  19:45  Oud-Heverlee Leuven             Standard   2.0
# 5   B1 2024-08-31  17:15         Beerschot VA               Dender   1.0
# 6   B1 2024-08-31  15:00             Mechelen            Charleroi   5.0
# 7   B1 2024-08-30  19:45                 Genk             Westerlo   1.0
# 8   B1 2024-08-25  18:15            Charleroi             Kortrijk   1.0
# 9   B1 2024-08-25  17:30             Standard         Beerschot VA   1.0
# 10  B1 2024-08-25  15:00           St Truiden         St. Gilloise   0.0
# 11  B1 2024-08-25  12:30               Dender          Club Brugge   1.0
# 12  B1 2024-08-24  19:45              Antwerp             Mechelen   0.0
# 13  B1 2024-08-24  17:15             Westerlo  Oud-Heverlee Leuven   1.0
# 14  B1 2024-08-18  18:15                 Gent             Westerlo   4.0
# 15  B1 2024-08-18  17:30             Kortrijk             Standard   1.0
# 16  B1 2024-08-18  15:00  Oud-Heverlee Leuven        Cercle Brugge   1.0
# 17  B1 2024-08-18  12:30          Club Brugge              Antwerp   1.0
# 18  B1 2024-08-17  19:45             Mechelen           Anderlecht   1.0
# 19  B1 2024-08-17  17:15           St Truiden               Dender   3.0
# 20  B1 2024-08-17  15:00         Beerschot VA                 Genk   3.0
# 21  B1 2024-08-16  19:45         St. Gilloise            Charleroi   1.0
# 22  B1 2024-08-11  18:15        Cercle Brugge         Beerschot VA   4.0
# 23  B1 2024-08-11  17:30            Charleroi                 Gent   1.0
# 24  B1 2024-08-11  15:00              Antwerp           St Truiden   6.0
# 25  B1 2024-08-11  12:30                 Genk          Club Brugge   3.0
# 26  B1 2024-08-10  19:45           Anderlecht  Oud-Heverlee Leuven   1.0
# 27  B1 2024-08-10  17:15             Westerlo         St. Gilloise   4.0
# 28  B1 2024-08-10  15:00               Dender             Kortrijk   4.0
# 29  B1 2024-08-09  19:45             Standard             Mechelen   0.0
# 30  B1 2024-08-04  18:15                 Gent               Dender   1.0
# 31  B1 2024-08-04  17:30             Standard          Club Brugge   1.0
# 32  B1 2024-08-04  15:00        Cercle Brugge             Kortrijk   1.0
# 33  B1 2024-08-04  12:30              Antwerp           Anderlecht   1.0
# 34  B1 2024-08-03  19:45           St Truiden            Charleroi   1.0
# 35  B1 2024-08-03  17:15  Oud-Heverlee Leuven                 Genk   3.0
# 36  B1 2024-08-03  15:00             Mechelen             Westerlo   2.0
# 37  B1 2024-08-02  19:45         St. Gilloise         Beerschot VA   3.0
# 38  B1 2024-07-28  18:15             Westerlo        Cercle Brugge   3.0
# 39  B1 2024-07-28  17:30            Charleroi              Antwerp   0.0
# 40  B1 2024-07-28  15:00             Kortrijk                 Gent   0.0
# 41  B1 2024-07-28  12:30                 Genk             Standard   0.0
# 42  B1 2024-07-27  19:45           Anderlecht           St Truiden   1.0
# 43  B1 2024-07-27  17:15         Beerschot VA  Oud-Heverlee Leuven   0.0
# 44  B1 2024-07-27  15:00               Dender         St. Gilloise   0.0
# 45  B1 2024-07-26  19:45          Club Brugge             Mechelen   1.0
# 46  B1 2024-06-02  12:30                 Genk                 Gent   0.0
# 47  B1 2024-05-26  17:30              Antwerp           Anderlecht   3.0
# 48  B1 2024-05-26  17:30          Club Brugge        Cercle Brugge   0.0
# 49  B1 2024-05-26  17:30         St. Gilloise                 Genk   2.0
#
#     FTAG FTR  HTHG  HTAG  ...    avgHST     avgHR  avgHomeWinOdds  \
# 0    1.0   D   0.0   1.0  ...  5.666667  0.000000        3.240000
# 1    0.0   D   0.0   0.0  ...  4.666667  0.000000        1.730000
# 2    1.0   D   1.0   1.0  ...  6.333333  0.000000        1.903333
# 3    0.0   H   2.0   0.0  ...  7.333333  0.000000        1.556667
# 4    0.0   H   1.0   0.0  ...  5.000000  0.333333        2.686667
# 5    2.0   A   0.0   2.0  ...  3.666667  0.000000        3.440000
# 6    2.0   H   3.0   2.0  ...  6.666667  0.000000        2.620000
# 7    0.0   H   0.0   0.0  ...  5.000000  0.000000        2.170000
# 8    0.0   H   1.0   0.0  ...  4.333333  0.000000        2.573333
# 9    0.0   H   0.0   0.0  ...  3.000000  0.000000        3.223333
# 10   0.0   D   0.0   0.0  ...  2.000000  0.333333        3.643333
# 11   2.0   A   1.0   2.0  ...  3.666667  0.000000        4.636667
# 12   1.0   A   0.0   1.0  ...  6.333333  0.000000        1.886667
# 13   1.0   D   1.0   1.0  ...  6.000000  0.000000        2.836667
# 14   1.0   H   3.0   1.0  ...  6.333333  0.000000        1.903333
# 15   0.0   H   0.0   0.0  ...  5.666667  0.000000        3.240000
# 16   1.0   D   1.0   1.0  ...  5.000000  0.333333        2.686667
# 17   0.0   H   0.0   0.0  ...  7.333333  0.000000        1.556667
# 18   3.0   A   1.0   2.0  ...  6.666667  0.000000        2.620000
# 19   3.0   D   2.0   1.0  ...  2.000000  0.333333        3.643333
# 20   4.0   A   1.0   3.0  ...  3.666667  0.000000        3.440000
# 21   0.0   H   0.0   0.0  ...  4.666667  0.000000        1.730000
# 22   1.0   H   3.0   1.0  ...  7.000000  0.000000        1.575000
# 23   0.0   H   0.0   0.0  ...  4.333333  0.000000        2.573333
# 24   1.0   H   2.0   0.0  ...  6.333333  0.000000        1.886667
# 25   2.0   H   0.0   1.0  ...  5.000000  0.000000        2.170000
# 26   1.0   D   1.0   1.0  ...  2.500000  0.000000        1.715000
# 27   3.0   H   3.0   1.0  ...  6.000000  0.000000        2.836667
# 28   1.0   H   2.0   1.0  ...  3.666667  0.000000        4.636667
# 29   0.0   D   0.0   0.0  ...  3.000000  0.000000        3.223333
# 30   2.0   A   0.0   1.0  ...  6.333333  0.000000        1.903333
# 31   0.0   H   0.0   0.0  ...  3.000000  0.000000        3.223333
# 32   2.0   A   1.0   1.0  ...  7.000000  0.000000        1.575000
# 33   2.0   A   1.0   1.0  ...  6.333333  0.000000        1.886667
# 34   4.0   A   0.0   4.0  ...  2.000000  0.333333        3.643333
# 35   1.0   H   2.0   0.0  ...  5.000000  0.333333        2.686667
# 36   4.0   A   0.0   2.0  ...  6.666667  0.000000        2.620000
# 37   1.0   H   2.0   0.0  ...  4.666667  0.000000        1.730000
# 38   0.0   H   1.0   0.0  ...  6.000000  0.000000        2.836667
# 39   1.0   A   0.0   1.0  ...  4.333333  0.000000        2.573333
# 40   1.0   A   0.0   0.0  ...  5.666667  0.000000        3.240000
# 41   0.0   D   0.0   0.0  ...  5.000000  0.000000        2.170000
# 42   0.0   H   0.0   0.0  ...  2.500000  0.000000        1.715000
# 43   0.0   D   0.0   0.0  ...  3.666667  0.000000        3.440000
# 44   0.0   D   0.0   0.0  ...  3.666667  0.000000        4.636667
# 45   1.0   D   0.0   0.0  ...  7.333333  0.000000        1.556667
# 46   1.0   A   0.0   0.0  ...  5.619048  0.095238        1.927143
# 47   1.0   H   0.0   1.0  ...  5.350000  0.000000        2.119000
# 48   0.0   D   0.0   0.0  ...  6.200000  0.050000        1.605000
# 49   0.0   H   1.0   0.0  ...  6.750000  0.000000        1.651500
#
#     avgHomeDrawOdds     avgAG    avgHAG    avgAST     avgAR  avgAwayWinOdds  \
# 0          3.643333  0.666667  0.333333  3.333333  0.000000        5.553333
# 1          4.200000  1.666667  1.000000  5.666667  0.000000        2.620000
# 2          4.263333  0.666667  0.666667  5.666667  0.333333        2.986667
# 3          4.436667  0.333333  0.333333  4.000000  0.000000        3.410000
# 4          3.456667  0.000000  0.000000  0.333333  0.333333        4.283333
# 5          3.606667  2.333333  1.333333  5.333333  0.000000        4.470000
# 6          3.663333  2.000000  2.000000  4.666667  0.000000        3.180000
# 7          4.130000  1.666667  1.000000  5.666667  0.000000        3.890000
# 8          3.623333  1.000000  0.666667  3.000000  0.333333        4.206667
# 9          3.870000  0.666667  0.333333  2.333333  0.333333        5.913333
# 10         3.733333  1.000000  0.333333  4.000000  0.000000        1.623333
# 11         4.200000  1.333333  1.000000  5.666667  0.000000        1.713333
# 12         4.186667  0.666667  0.333333  2.666667  0.000000        5.300000
# 13         3.650000  0.666667  0.666667  4.000000  0.000000        3.293333
# 14         4.263333  1.666667  1.000000  5.666667  0.000000        3.890000
# 15         3.643333  0.000000  0.000000  0.333333  0.333333        4.283333
# 16         3.456667  0.333333  0.333333  4.000000  0.000000        3.410000
# 17         4.436667  0.666667  0.666667  5.666667  0.333333        2.986667
# 18         3.663333  1.666667  1.000000  5.666667  0.000000        2.620000
# 19         3.733333  2.333333  1.333333  5.333333  0.000000        4.470000
# 20         3.606667  2.500000  1.500000  6.500000  0.500000        1.880000
# 21         4.200000  2.000000  2.000000  4.666667  0.000000        3.180000
# 22         4.260000  0.666667  0.333333  2.333333  0.333333        5.913333
# 23         3.623333  0.500000  0.000000  1.000000  0.000000        1.950000
# 24         4.186667  0.666667  0.333333  3.333333  0.000000        5.553333
# 25         4.130000  1.333333  1.000000  5.666667  0.000000        1.713333
# 26         3.935000  0.666667  0.666667  4.000000  0.000000        3.293333
# 27         3.650000  1.000000  0.333333  4.000000  0.000000        1.623333
# 28         4.200000  1.000000  0.666667  3.000000  0.333333        4.206667
# 29         3.870000  0.666667  0.333333  2.666667  0.000000        5.300000
# 30         4.263333  2.333333  1.333333  5.333333  0.000000        4.470000
# 31         3.870000  1.333333  1.000000  5.666667  0.000000        1.713333
# 32         4.260000  1.000000  0.666667  3.000000  0.333333        4.206667
# 33         4.186667  1.666667  1.000000  5.666667  0.000000        2.620000
# 34         3.733333  2.000000  2.000000  4.666667  0.000000        3.180000
# 35         3.456667  2.500000  1.500000  6.500000  0.500000        1.880000
# 36         3.663333  1.666667  1.000000  5.666667  0.000000        3.890000
# 37         4.200000  0.666667  0.333333  2.333333  0.333333        5.913333
# 38         3.650000  0.333333  0.333333  4.000000  0.000000        3.410000
# 39         3.623333  0.666667  0.666667  5.666667  0.333333        2.986667
# 40         3.643333  0.500000  0.000000  1.000000  0.000000        1.950000
# 41         4.130000  0.000000  0.000000  0.333333  0.333333        4.283333
# 42         3.935000  0.666667  0.333333  3.333333  0.000000        5.553333
# 43         3.606667  0.666667  0.666667  4.000000  0.000000        3.293333
# 44         4.200000  1.000000  0.333333  4.000000  0.000000        1.623333
# 45         4.436667  0.666667  0.333333  2.666667  0.000000        5.300000
# 46         4.219048  1.619048  0.809524  5.380952  0.190476        2.393810
# 47         4.158000  1.600000  0.850000  5.000000  0.100000        2.681500
# 48         4.715000  1.150000  0.450000  4.050000  0.150000        3.108000
# 49         4.580000  1.300000  0.550000  4.900000  0.200000        2.670000
#
#     avgAwayDrawOdds
# 0          4.216667
# 1          3.576667
# 2          3.693333
# 3          3.806667
# 4          3.730000
# 5          4.013333
# 6          3.543333
# 7          4.063333
# 8          3.773333
# 9          4.443333
# 10         4.296667
# 11         4.106667
# 12         4.190000
# 13         3.510000
# 14         4.063333
# 15         3.730000
# 16         3.806667
# 17         3.693333
# 18         3.576667
# 19         4.013333
# 20         3.830000
# 21         3.543333
# 22         4.443333
# 23         3.915000
# 24         4.216667
# 25         4.106667
# 26         3.510000
# 27         4.296667
# 28         3.773333
# 29         4.190000
# 30         4.013333
# 31         4.106667
# 32         3.773333
# 33         3.576667
# 34         3.543333
# 35         3.830000
# 36         4.063333
# 37         4.443333
# 38         3.806667
# 39         3.693333
# 40         3.915000
# 41         3.730000
# 42         4.216667
# 43         3.510000
# 44         4.296667
# 45         4.190000
# 46         3.842381
# 47         3.702500
# 48         3.808500
# 49         3.817500
#
# [50 rows x 43 columns]
